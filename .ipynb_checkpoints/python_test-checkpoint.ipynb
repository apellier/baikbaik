# %%
import pandas as pd
import numpy as np

velib_data = pd.read_csv("data_test/velib_data.csv")

# %%
# See the first five rows
velib_data.head()
# Out:
#      ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# 0  1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 1  1,807,295,310  9.425151e+16         821238            V-Plus    195.0
# 2  1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 3  1,847,609,163  9.425151e+16         821238            V-Plus   7840.0
# 4  1,851,069,210  9.425151e+16         821238            V-Plus  22372.0
#
#   Type de vélo  Version vBox Date/heure de début de la location  \
# 0           VM          3.38                    7/24/2019 11:55
# 1           VM          3.38                    7/24/2019 14:14
# 2           VM          3.38                    7/28/2019 14:20
# 3           VM          3.38                     7/29/2019 7:31
# 4           VM          3.38                    7/29/2019 16:28
#
#    ID station départ                   Nom station départ  CP station départ  \
# 0              10025      Jemmapes - Ecluses Saint-Martin              75010
# 1               4104               Sebastopol - Rambuteau              75004
# 2              10151  Gare du Nord - Faubourg Saint-Denis              75010
# 3              17108          Bessières - Porte de Clichy              75017
# 4              17108          Bessières - Porte de Clichy              75017
#
#   Ville départ Date/heure de fin de la location  ID station arrivée  \
# 0     PARIS 10                  7/24/2019 12:11                4104
# 1     PARIS 04                  7/24/2019 14:32               10025
# 2     PARIS 10                  7/28/2019 14:23               10026
# 3     PARIS 17                   7/29/2019 7:41               17023
# 4     PARIS 17                  7/29/2019 16:50               10162
#
#                 Nom station arrivée  CP station arrivée Ville arrivée  \
# 0            Sebastopol - Rambuteau               75004      PARIS 04
# 1   Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 2    Gare de l'Est - Chateau Landon               75010      PARIS 10
# 3                  Porte d'Asnières               75017      PARIS 17
# 4  Alexandre Parodi - Quai de Valmy               75010      PARIS 10
#
#    Durée location (mn)  Distance parcourue en mètres  \
# 0                16.48                          2721
# 1                18.30                          3087
# 2                 2.63                           553
# 3                10.11                          2131
# 4                22.43                          5787
#
#    Montant de la course en euros
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0

# %%
# get the number of missing data points per column
missing_values_count = velib_data.isnull().sum()

missing_values_count
# Out:
# ID location                           0
# ID abonné                             0
# ID Abonnement                         0
# Type d'abonnement                     0
# ID Vélo                               5
# Type de vélo                          5
# Version vBox                          9
# Date/heure de début de la location    0
# ID station départ                     0
# Nom station départ                    0
# CP station départ                     0
# Ville départ                          0
# Date/heure de fin de la location      0
# ID station arrivée                    0
# Nom station arrivée                   0
# CP station arrivée                    0
# Ville arrivée                         0
# Durée location (mn)                   0
# Distance parcourue en mètres          0
# Montant de la course en euros         0
# dtype: int64

# %%
# how many total missing values do we have ? 
total_cells = np.product(velib_data.shape)
total_missing = missing_values_count.sum()

print(total_cells)
print(total_missing)

# percent of data that is missing
percent_missing =(total_missing/total_cells)*100
percent_missing
# Out:
# 8240
# 19
# 0.23058252427184464

# %%
velib_data.shape
velib_data.columns
# Out:
# Index(['ID location', 'ID abonné', 'ID Abonnement', 'Type d'abonnement',
#        'ID Vélo', 'Type de vélo', 'Version vBox',
#        'Date/heure de début de la location', 'ID station départ',
#        'Nom station départ', 'CP station départ', 'Ville départ',
#        'Date/heure de fin de la location', 'ID station arrivée',
#        'Nom station arrivée', 'CP station arrivée', 'Ville arrivée',
#        'Durée location (mn)', 'Distance parcourue en mètres',
#        'Montant de la course en euros'],
#       dtype='object')

# %%
velib_data = velib_data.drop(velib_data.columns[6], axis=1)
missing_values_count = velib_data.isnull().sum()

missing_values_count
# Out:
# ID location                           0
# ID abonné                             0
# ID Abonnement                         0
# Type d'abonnement                     0
# ID Vélo                               5
# Type de vélo                          5
# Date/heure de début de la location    0
# ID station départ                     0
# Nom station départ                    0
# CP station départ                     0
# Ville départ                          0
# Date/heure de fin de la location      0
# ID station arrivée                    0
# Nom station arrivée                   0
# CP station arrivée                    0
# Ville arrivée                         0
# Durée location (mn)                   0
# Distance parcourue en mètres          0
# Montant de la course en euros         0
# dtype: int64

# %%
velib_data.iloc[22]
# Out:
# ID location                                                       1,916,227,662
# ID abonné                                                           9.42515e+16
# ID Abonnement                                                            821238
# Type d'abonnement                                                        V-Plus
# ID Vélo                                                                   23312
# Type de vélo                                                                 VM
# Date/heure de début de la location                               8/8/2019 16:40
# ID station départ                                                         10165
# Nom station départ                    Gare de l'Est - Place du 11 Novembre 1918
# CP station départ                                                         75010
# Ville départ                                                           PARIS 10
# Date/heure de fin de la location                                 8/8/2019 16:43
# ID station arrivée                                                        10162
# Nom station arrivée                            Alexandre Parodi - Quai de Valmy
# CP station arrivée                                                        75010
# Ville arrivée                                                          PARIS 10
# Durée location (mn)                                                        3.51
# Distance parcourue en mètres                                                914
# Montant de la course en euros                                                 0
# Name: 22, dtype: object

# %%
velib_data['Type d\'abonnement'] == "V-Plus"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 407    False
# 408    False
# 409     True
# 410     True
# 411     True
# Name: Type d'abonnement, Length: 412, dtype: bool

# %%
velib_data.loc[velib_data['Type d\'abonnement'] == "V-Plus"]
# Out:
#        ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# 0    1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 1    1,807,295,310  9.425151e+16         821238            V-Plus    195.0
# 2    1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 3    1,847,609,163  9.425151e+16         821238            V-Plus   7840.0
# 4    1,851,069,210  9.425151e+16         821238            V-Plus  22372.0
# ..             ...           ...            ...               ...      ...
# 207  4,793,365,363  9.425151e+16         821238            V-Plus   3478.0
# 208  4,793,373,124  9.425151e+16         821238            V-Plus   3478.0
# 409     76,788,279  9.425151e+16         166792            V-Plus   8945.0
# 410     81,937,517  9.425151e+16         166792            V-Plus   7881.0
# 411    108,634,680  9.425151e+16         166792            V-Plus   7786.0
#
#     Type de vélo Date/heure de début de la location  ID station départ  \
# 0             VM                    7/24/2019 11:55              10025
# 1             VM                    7/24/2019 14:14               4104
# 2             VM                    7/28/2019 14:20              10151
# 3             VM                     7/29/2019 7:31              17108
# 4             VM                    7/29/2019 16:28              17108
# ..           ...                                ...                ...
# 207           VM                    5/26/2020 20:13              10037
# 208           VM                    5/26/2020 20:13              10037
# 409           VM                     3/9/2018 18:38              20024
# 410           VM                     3/16/2018 0:15              19115
# 411           VM                     4/4/2018 12:57               7005
#
#                       Nom station départ  CP station départ Ville départ  \
# 0        Jemmapes - Ecluses Saint-Martin              75010     PARIS 10
# 1                 Sebastopol - Rambuteau              75004     PARIS 04
# 2    Gare du Nord - Faubourg Saint-Denis              75010     PARIS 10
# 3            Bessières - Porte de Clichy              75017     PARIS 17
# 4            Bessières - Porte de Clichy              75017     PARIS 17
# ..                                   ...                ...          ...
# 207                        Quai de Valmy              75010     PARIS 10
# 208                        Quai de Valmy              75010     PARIS 10
# 409             Gambetta - Père Lachaise              75020     PARIS 20
# 410                 Porte de la Villette              75019     PARIS 19
# 411                        Raspail - Bac              75007     PARIS 07
#
#     Date/heure de fin de la location  ID station arrivée  \
# 0                    7/24/2019 12:11                4104
# 1                    7/24/2019 14:32               10025
# 2                    7/28/2019 14:23               10026
# 3                     7/29/2019 7:41               17023
# 4                    7/29/2019 16:50               10162
# ..                               ...                 ...
# 207                  5/26/2020 20:13               10037
# 208                  5/26/2020 20:18               19002
# 409                   3/9/2018 18:42               20024
# 410                   3/16/2018 9:49               10025
# 411                   4/4/2018 13:14               14025
#
#                   Nom station arrivée  CP station arrivée Ville arrivée  \
# 0              Sebastopol - Rambuteau               75004      PARIS 04
# 1     Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 2      Gare de l'Est - Chateau Landon               75010      PARIS 10
# 3                    Porte d'Asnières               75017      PARIS 17
# 4    Alexandre Parodi - Quai de Valmy               75010      PARIS 10
# ..                                ...                 ...           ...
# 207                     Quai de Valmy               75010      PARIS 10
# 208                        Centquatre               75019      PARIS 19
# 409          Gambetta - Père Lachaise               75020      PARIS 20
# 410   Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 411                  Jacquier - Didot               75014      PARIS 14
#
#      Durée location (mn)  Distance parcourue en mètres  \
# 0                  16.48                          2721
# 1                  18.30                          3087
# 2                   2.63                           553
# 3                  10.11                          2131
# 4                  22.43                          5787
# ..                   ...                           ...
# 207                 0.06                             0
# 208                 4.63                          1166
# 409                 4.38                           181
# 410                 0.25                             0
# 411                16.35                          3513
#
#      Montant de la course en euros
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ..                             ...
# 207                              0
# 208                              0
# 409                              0
# 410                              0
# 411                              0
#
# [212 rows x 19 columns]

# %%
velib_data.loc[(velib_data['Type d\'abonnement'] == "V-Plus") & (velib_data['CP station départ'] == 75010)]
# Out:
#        ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# 0    1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 2    1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 8    1,865,334,483  9.425151e+16         821238            V-Plus  20095.0
# 11   1,881,296,051  9.425151e+16         821238            V-Plus   2276.0
# 12   1,881,974,649  9.425151e+16         821238            V-Plus   7409.0
# ..             ...           ...            ...               ...      ...
# 202  4,750,600,062  9.425151e+16         821238            V-Plus  16164.0
# 204  4,756,987,232  9.425151e+16         821238            V-Plus  23786.0
# 206  4,767,974,508  9.425151e+16         821238            V-Plus   9366.0
# 207  4,793,365,363  9.425151e+16         821238            V-Plus   3478.0
# 208  4,793,373,124  9.425151e+16         821238            V-Plus   3478.0
#
#     Type de vélo Date/heure de début de la location  ID station départ  \
# 0             VM                    7/24/2019 11:55              10025
# 2             VM                    7/28/2019 14:20              10151
# 8             VM                    7/31/2019 17:15              10037
# 11            VM                     8/3/2019 12:21              10014
# 12            VM                     8/3/2019 14:27              10162
# ..           ...                                ...                ...
# 202           VM                    5/23/2020 23:26              10162
# 204           VM                    5/24/2020 14:46              10110
# 206           VM                    5/25/2020 10:55              10162
# 207           VM                    5/26/2020 20:13              10037
# 208           VM                    5/26/2020 20:13              10037
#
#                       Nom station départ  CP station départ Ville départ  \
# 0        Jemmapes - Ecluses Saint-Martin              75010     PARIS 10
# 2    Gare du Nord - Faubourg Saint-Denis              75010     PARIS 10
# 8                          Quai de Valmy              75010     PARIS 10
# 11               Marseille - Beaurepaire              75010     PARIS 10
# 12      Alexandre Parodi - Quai de Valmy              75010     PARIS 10
# ..                                   ...                ...          ...
# 202     Alexandre Parodi - Quai de Valmy              75010     PARIS 10
# 204               Louis Blanc - Jemmapes              75010     PARIS 10
# 206     Alexandre Parodi - Quai de Valmy              75010     PARIS 10
# 207                        Quai de Valmy              75010     PARIS 10
# 208                        Quai de Valmy              75010     PARIS 10
#
#     Date/heure de fin de la location  ID station arrivée  \
# 0                    7/24/2019 12:11                4104
# 2                    7/28/2019 14:23               10026
# 8                    7/31/2019 17:19               19005
# 11                    8/3/2019 12:25               10161
# 12                    8/3/2019 14:31               10036
# ..                               ...                 ...
# 202                  5/23/2020 23:41               19002
# 204                  5/24/2020 14:52               19002
# 206                  5/25/2020 11:02               19014
# 207                  5/26/2020 20:13               10037
# 208                  5/26/2020 20:18               19002
#
#                        Nom station arrivée  CP station arrivée Ville arrivée  \
# 0                   Sebastopol - Rambuteau               75004      PARIS 04
# 2           Gare de l'Est - Chateau Landon               75010      PARIS 10
# 8                         Flandre - Riquet               75019      PARIS 19
# 11   Gare de l'Est - Faubourg-Saint-Martin               75010      PARIS 10
# 12                      Aqueduc - Villette               75010      PARIS 10
# ..                                     ...                 ...           ...
# 202                             Centquatre               75019      PARIS 19
# 204                             Centquatre               75019      PARIS 19
# 206                 Lorraine - Jean Jaurès               75019      PARIS 19
# 207                          Quai de Valmy               75010      PARIS 10
# 208                             Centquatre               75019      PARIS 19
#
#      Durée location (mn)  Distance parcourue en mètres  \
# 0                  16.48                          2721
# 2                   2.63                           553
# 8                   4.26                          1020
# 11                  3.63                           886
# 12                  3.38                           723
# ..                   ...                           ...
# 202                15.01                          1862
# 204                 5.75                          1457
# 206                 6.86                          1616
# 207                 0.06                             0
# 208                 4.63                          1166
#
#      Montant de la course en euros
# 0                                0
# 2                                0
# 8                                0
# 11                               0
# 12                               0
# ..                             ...
# 202                              0
# 204                              0
# 206                              0
# 207                              0
# 208                              0
#
# [94 rows x 19 columns]

# %%
velib_data.loc[(velib_data['Type d\'abonnement'] == "V-Plus") | (velib_data['CP station départ'] == 75010)]
# Out:
#        ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# 0    1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 1    1,807,295,310  9.425151e+16         821238            V-Plus    195.0
# 2    1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 3    1,847,609,163  9.425151e+16         821238            V-Plus   7840.0
# 4    1,851,069,210  9.425151e+16         821238            V-Plus  22372.0
# ..             ...           ...            ...               ...      ...
# 399  6,820,029,562  9.425151e+16        1378981             V-Max  21161.0
# 404  6,846,752,267  9.425151e+16        1378981             V-Max  36477.0
# 409     76,788,279  9.425151e+16         166792            V-Plus   8945.0
# 410     81,937,517  9.425151e+16         166792            V-Plus   7881.0
# 411    108,634,680  9.425151e+16         166792            V-Plus   7786.0
#
#     Type de vélo Date/heure de début de la location  ID station départ  \
# 0             VM                    7/24/2019 11:55              10025
# 1             VM                    7/24/2019 14:14               4104
# 2             VM                    7/28/2019 14:20              10151
# 3             VM                     7/29/2019 7:31              17108
# 4             VM                    7/29/2019 16:28              17108
# ..           ...                                ...                ...
# 399           VM                     9/23/2020 8:20              10026
# 404          VAE                    9/24/2020 13:12              10026
# 409           VM                     3/9/2018 18:38              20024
# 410           VM                     3/16/2018 0:15              19115
# 411           VM                     4/4/2018 12:57               7005
#
#                       Nom station départ  CP station départ Ville départ  \
# 0        Jemmapes - Ecluses Saint-Martin              75010     PARIS 10
# 1                 Sebastopol - Rambuteau              75004     PARIS 04
# 2    Gare du Nord - Faubourg Saint-Denis              75010     PARIS 10
# 3            Bessières - Porte de Clichy              75017     PARIS 17
# 4            Bessières - Porte de Clichy              75017     PARIS 17
# ..                                   ...                ...          ...
# 399       Gare de l'Est - Chateau Landon              75010     PARIS 10
# 404       Gare de l'Est - Chateau Landon              75010     PARIS 10
# 409             Gambetta - Père Lachaise              75020     PARIS 20
# 410                 Porte de la Villette              75019     PARIS 19
# 411                        Raspail - Bac              75007     PARIS 07
#
#     Date/heure de fin de la location  ID station arrivée  \
# 0                    7/24/2019 12:11                4104
# 1                    7/24/2019 14:32               10025
# 2                    7/28/2019 14:23               10026
# 3                     7/29/2019 7:41               17023
# 4                    7/29/2019 16:50               10162
# ..                               ...                 ...
# 399                   9/23/2020 8:30                1002
# 404                  9/24/2020 13:26               17110
# 409                   3/9/2018 18:42               20024
# 410                   3/16/2018 9:49               10025
# 411                   4/4/2018 13:14               14025
#
#                   Nom station arrivée  CP station arrivée Ville arrivée  \
# 0              Sebastopol - Rambuteau               75004      PARIS 04
# 1     Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 2      Gare de l'Est - Chateau Landon               75010      PARIS 10
# 3                    Porte d'Asnières               75017      PARIS 17
# 4    Alexandre Parodi - Quai de Valmy               75010      PARIS 10
# ..                                ...                 ...           ...
# 399      Victoria - Place du Chatelet               75001      PARIS 01
# 404                 Legendre - Nollet               75017      PARIS 17
# 409          Gambetta - Père Lachaise               75020      PARIS 20
# 410   Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 411                  Jacquier - Didot               75014      PARIS 14
#
#      Durée location (mn)  Distance parcourue en mètres  \
# 0                  16.48                          2721
# 1                  18.30                          3087
# 2                   2.63                           553
# 3                  10.11                          2131
# 4                  22.43                          5787
# ..                   ...                           ...
# 399                10.26                          2899
# 404                14.45                          3991
# 409                 4.38                           181
# 410                 0.25                             0
# 411                16.35                          3513
#
#      Montant de la course en euros
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ..                             ...
# 399                              0
# 404                              0
# 409                              0
# 410                              0
# 411                              0
#
# [267 rows x 19 columns]

# %%
velib_data.loc[velib_data.col_name.isin(['75010', '75014'])
# Out:
#   File "<ipython-input-12-01094bb50d8d>", line 1
#     velib_data.loc[velib_data.col_name.isin(['75010', '75014'])
#                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
# isnull() notnull()

# %%
velib_data.loc[velib_data["Type de vélo"].isnull()]

# %%
velib_data["Distance parcourue en mètres"].describe()

# %%
velib_data["Type d'abonnement"].describe()

# %%
velib_data["Ville arrivée"].unique()

# %%
velib_data["Ville arrivée"].value_counts()

# %%
distance = velib_data["Distance parcourue en mètres"].mean()
velib_data["Distance parcourue en mètres"].map(lambda p : p - distance)

# %%
# apply()

# %%
velib_data["Ville arrivée"] + "-" + str(velib_data["CP station arrivée"])

# %%
n_trop = reviews.description.map(lambda desc: "tropical" in desc).sum()
n_fruity = reviews.description.map(lambda desc: "fruity" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])

# %%
velib_data.groupby("Ville arrivée")

# %%
velib_data.groupby("Ville départ")["Distance parcourue en mètres"].min()

# %%
velib_data.groupby("Ville départ").apply(lambda df : df["Ville arrivée"].iloc[0])

# %%
velib_data.groupby(["Ville départ", "Ville arrivée"]).apply(lambda df: df.loc[df["Distance parcourue en mètres"].idxmin()])

# %%
velib_data.groupby(["Ville départ", "Ville arrivée"])["Distance parcourue en mètres"].agg([len, min, max])

# %%
start_end = velib_data.groupby(["Ville départ", "Ville arrivée"])["Distance parcourue en mètres"].agg([len, min, max])
start_end.reset_index()

# %%
start_end = velib_data.groupby(["Ville départ", "Ville arrivée"])["Distance parcourue en mètres"].agg([len, min, max])
start_end.sort_values(by="len", ascending=False)

# %%
start_end = velib_data.groupby(["Ville départ", "Ville arrivée"])["Distance parcourue en mètres"].agg([len, min, max])
start_end.sort_values(by=["max", "min"])

# %%
velib_data[pd.isnull(velib_data["Type de vélo"])]

# %%
velib_data["Type de vélo"].replace("NaN","Unknown")

# %%
velib_data[pd.isnull(velib_data["ID Vélo"])]

# %%
velib_data.rename(columns={"Distance parcourue en mètres": "distance"})

# %%
velib_data.rename(columns={0: 'id_location', 1: 'id_subscriber'})

# %%
velib_data.rename_axis("tags", axis="columns").rename_axis("ways", axis="rows")
# Out:
# tags    ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# ways
# 0     1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 1     1,807,295,310  9.425151e+16         821238            V-Plus    195.0
# 2     1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 3     1,847,609,163  9.425151e+16         821238            V-Plus   7840.0
# 4     1,851,069,210  9.425151e+16         821238            V-Plus  22372.0
# ...             ...           ...            ...               ...      ...
# 407   6,946,814,980  9.425151e+16        1378981             V-Max  41619.0
# 408   7,142,763,817  9.425151e+16        1378981             V-Max  13790.0
# 409      76,788,279  9.425151e+16         166792            V-Plus   8945.0
# 410      81,937,517  9.425151e+16         166792            V-Plus   7881.0
# 411     108,634,680  9.425151e+16         166792            V-Plus   7786.0
#
# tags Type de vélo Date/heure de début de la location  ID station départ  \
# ways
# 0              VM                    7/24/2019 11:55              10025
# 1              VM                    7/24/2019 14:14               4104
# 2              VM                    7/28/2019 14:20              10151
# 3              VM                     7/29/2019 7:31              17108
# 4              VM                    7/29/2019 16:28              17108
# ...           ...                                ...                ...
# 407           VAE                    9/30/2020 15:45               7018
# 408           VAE                   10/12/2020 16:09              13106
# 409            VM                     3/9/2018 18:38              20024
# 410            VM                     3/16/2018 0:15              19115
# 411            VM                     4/4/2018 12:57               7005
#
# tags                   Nom station départ  CP station départ Ville départ  \
# ways
# 0         Jemmapes - Ecluses Saint-Martin              75010     PARIS 10
# 1                  Sebastopol - Rambuteau              75004     PARIS 04
# 2     Gare du Nord - Faubourg Saint-Denis              75010     PARIS 10
# 3             Bessières - Porte de Clichy              75017     PARIS 17
# 4             Bessières - Porte de Clichy              75017     PARIS 17
# ...                                   ...                ...          ...
# 407                     Ségur - d'Estrées              75007     PARIS 07
# 408                Bobillot - Paulin Mery              75013     PARIS 13
# 409              Gambetta - Père Lachaise              75020     PARIS 20
# 410                  Porte de la Villette              75019     PARIS 19
# 411                         Raspail - Bac              75007     PARIS 07
#
# tags Date/heure de fin de la location  ID station arrivée  \
# ways
# 0                     7/24/2019 12:11                4104
# 1                     7/24/2019 14:32               10025
# 2                     7/28/2019 14:23               10026
# 3                      7/29/2019 7:41               17023
# 4                     7/29/2019 16:50               10162
# ...                               ...                 ...
# 407                   9/30/2020 16:08               10016
# 408                  10/12/2020 16:12               13024
# 409                    3/9/2018 18:42               20024
# 410                    3/16/2018 9:49               10025
# 411                    4/4/2018 13:14               14025
#
# tags               Nom station arrivée  CP station arrivée Ville arrivée  \
# ways
# 0               Sebastopol - Rambuteau               75004      PARIS 04
# 1      Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 2       Gare de l'Est - Chateau Landon               75010      PARIS 10
# 3                     Porte d'Asnières               75017      PARIS 17
# 4     Alexandre Parodi - Quai de Valmy               75010      PARIS 10
# ...                                ...                 ...           ...
# 407        Récollets - Square Villemin               75010      PARIS 10
# 408                 Bobillot - Tolbiac               75013      PARIS 13
# 409           Gambetta - Père Lachaise               75020      PARIS 20
# 410    Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 411                   Jacquier - Didot               75014      PARIS 14
#
# tags  Durée location (mn)  Distance parcourue en mètres  \
# ways
# 0                   16.48                          2721
# 1                   18.30                          3087
# 2                    2.63                           553
# 3                   10.11                          2131
# 4                   22.43                          5787
# ...                   ...                           ...
# 407                 22.70                          6839
# 408                  2.98                           560
# 409                  4.38                           181
# 410                  0.25                             0
# 411                 16.35                          3513
#
# tags  Montant de la course en euros
# ways
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 407                               0
# 408                               0
# 409                               0
# 410                               0
# 411                               0
#
# [412 rows x 19 columns]

# %%
"""first_ds = pd.read_csv(...)
second_ds = pd.read_csv(...)

pd.concat([first_ds, second_ds])"""

# %%
"""
left = first_ds.set_index(["title", "trending_date"])
right = second_ds.set_index(["title", "trending_date"])

left.join(right, lsuffix="_FIRST", rsuffix="_SECOND")
"""

# %%
missing_values_count = velib_data.isnull().sum()
missing_values_count
# Out:
# ID location                           0
# ID abonné                             0
# ID Abonnement                         0
# Type d'abonnement                     0
# ID Vélo                               5
# Type de vélo                          5
# Date/heure de début de la location    0
# ID station départ                     0
# Nom station départ                    0
# CP station départ                     0
# Ville départ                          0
# Date/heure de fin de la location      0
# ID station arrivée                    0
# Nom station arrivée                   0
# CP station arrivée                    0
# Ville arrivée                         0
# Durée location (mn)                   0
# Distance parcourue en mètres          0
# Montant de la course en euros         0
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(velib_data.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.12774655084312722

# %%
# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
# from mlxtend.preprocessing import minmax_scaling

# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import datetime

# %%
velib_data.head()
# Out:
#      ID location     ID abonné  ID Abonnement Type d'abonnement  ID Vélo  \
# 0  1,806,565,011  9.425151e+16         821238            V-Plus  21329.0
# 1  1,807,295,310  9.425151e+16         821238            V-Plus    195.0
# 2  1,843,776,641  9.425151e+16         821238            V-Plus  24339.0
# 3  1,847,609,163  9.425151e+16         821238            V-Plus   7840.0
# 4  1,851,069,210  9.425151e+16         821238            V-Plus  22372.0
#
#   Type de vélo Date/heure de début de la location  ID station départ  \
# 0           VM                    7/24/2019 11:55              10025
# 1           VM                    7/24/2019 14:14               4104
# 2           VM                    7/28/2019 14:20              10151
# 3           VM                     7/29/2019 7:31              17108
# 4           VM                    7/29/2019 16:28              17108
#
#                     Nom station départ  CP station départ Ville départ  \
# 0      Jemmapes - Ecluses Saint-Martin              75010     PARIS 10
# 1               Sebastopol - Rambuteau              75004     PARIS 04
# 2  Gare du Nord - Faubourg Saint-Denis              75010     PARIS 10
# 3          Bessières - Porte de Clichy              75017     PARIS 17
# 4          Bessières - Porte de Clichy              75017     PARIS 17
#
#   Date/heure de fin de la location  ID station arrivée  \
# 0                  7/24/2019 12:11                4104
# 1                  7/24/2019 14:32               10025
# 2                  7/28/2019 14:23               10026
# 3                   7/29/2019 7:41               17023
# 4                  7/29/2019 16:50               10162
#
#                 Nom station arrivée  CP station arrivée Ville arrivée  \
# 0            Sebastopol - Rambuteau               75004      PARIS 04
# 1   Jemmapes - Ecluses Saint-Martin               75010      PARIS 10
# 2    Gare de l'Est - Chateau Landon               75010      PARIS 10
# 3                  Porte d'Asnières               75017      PARIS 17
# 4  Alexandre Parodi - Quai de Valmy               75010      PARIS 10
#
#    Durée location (mn)  Distance parcourue en mètres  \
# 0                16.48                          2721
# 1                18.30                          3087
# 2                 2.63                           553
# 3                10.11                          2131
# 4                22.43                          5787
#
#    Montant de la course en euros
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0

# %%
print(velib_data["Date/heure de début de la location"].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date/heure de début de la location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-c015119367cb> in <module>
# ----> 1 print(velib_data["Date/heure de début de la location"].head())
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904                 indexer = [indexer]
#    2905         else:
# -> 2906             if is_iterator(key):
#    2907                 key = list(key)
#    2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Date/heure de début de la location'

# %%
# dropping null value columns to avoid errors 
velib_data.dropna(inplace = True) 
  
# new data frame with split value columns 
new = velib_data["Date/heure de début de la location"].str.split(expand = True) 

print(new)
# making separate first name column from new data frame 
velib_data["Date de début de location"]= new[0] 
  
# making separate last name column from new data frame 
velib_data["Heure de début de location"]= new[1] 
  
# Dropping old Name columns 
velib_data.drop(columns =["Date/heure de début de la location"], inplace = True) 
  
# df display 
velib_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date/heure de début de la location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f64b9b6d76ba> in <module>
#       3
#       4 # new data frame with split value columns
# ----> 5 new = velib_data["Date/heure de début de la location"].str.split(expand = True)
#       6
#       7 print(new)
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904                 indexer = [indexer]
#    2905         else:
# -> 2906             if is_iterator(key):
#    2907                 key = list(key)
#    2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Date/heure de début de la location'
